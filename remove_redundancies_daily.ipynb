# %%
import numpy as np
import pandas as pd

import seaborn as sns

from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image

# %%
def find_redundant_pairs(correlation_matrix, threshold):
    redundant_pairs = []
    # Iterate through the upper triangle of the correlation matrix
    for i in range(len(correlation_matrix.columns)):
        for j in range(i+1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) >= threshold:
                redundant_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j]))
    return redundant_pairs

# %%
# Read correlation matrix from CSV file
correlation_matrix_df = pd.read_excel('filt_CorrMatrix-Daily-AllFractures-wrtOHS&OKS_heatmap.xlsx', index_col=0)
correlation_matrix_df.head()
# Out:
#                            position-count  position-duration  \
# position-count                   1.000000           0.972221
# position-duration                0.972221           1.000000
# position-maximum-distance        0.807925           0.769776
# motion-sum                       0.140849           0.132288
# motion-ratio                     0.000000           0.000000
#
#                            position-maximum-distance  motion-sum  \
# position-count                              0.807925    0.140849
# position-duration                           0.769776    0.132288
# position-maximum-distance                   1.000000    0.210993
# motion-sum                                  0.210993    1.000000
# motion-ratio                                0.000000    0.339678
#
#                            motion-ratio  motion-mean  motion-max  \
# position-count                 0.000000     0.159361    0.156295
# position-duration              0.000000     0.149009    0.146339
# position-maximum-distance      0.000000     0.223331    0.210109
# motion-sum                     0.339678     0.920581    0.923681
# motion-ratio                   1.000000     0.000000    0.000000
#
#                            motion-max-timestamp  heartrate-min  heartrate-max  \
# position-count                         0.000000        0.00000       0.000000
# position-duration                      0.000000        0.00000       0.000000
# position-maximum-distance              0.000000        0.00000       0.000000
# motion-sum                             0.436195        0.00000       0.122864
# motion-ratio                           0.000000       -0.26763      -0.145652
#
#                            ...    oks-07    oks-08    oks-09    oks-10  \
# position-count             ...  0.000000  0.218864  0.148139  0.214737
# position-duration          ...  0.000000  0.204809  0.150876  0.230606
# position-maximum-distance  ... -0.174589  0.204322  0.000000  0.243063
# motion-sum                 ... -0.295007  0.402982  0.299288  0.631509
# motion-ratio               ... -0.489956  0.000000 -0.376669  0.171569
#
#                              oks-11    oks-12       oks       tug  chairstand  \
# position-count             0.000000  0.000000  0.000000  0.000000    0.000000
# position-duration          0.000000  0.121985  0.000000  0.000000    0.000000
# position-maximum-distance  0.000000  0.000000  0.000000  0.000000    0.000000
# motion-sum                 0.210568  0.352965  0.280779  0.402421   -0.226646
# motion-ratio              -0.502535 -0.278429 -0.442033  0.162845   -0.351745
#
#                                 sex
# position-count             0.000000
# position-duration          0.000000
# position-maximum-distance -0.143429
# motion-sum                 0.000000
# motion-ratio              -0.206125
#
# [5 rows x 90 columns]

# %%
# Find redundant pairs
redundant_pairs = find_redundant_pairs(correlation_matrix_df, threshold=0.9)

# %%
redundant_pairs_df = pd.DataFrame(redundant_pairs, columns=['Column 1', 'Column 2'])
redundant_pairs_df
# Out:
#                      Column 1                      Column 2
# 0              position-count             position-duration
# 1              position-count     Time spent outside (mins)
# 2              position-count  distance travelled from home
# 3           position-duration     Time spent outside (mins)
# 4           position-duration  distance travelled from home
# 5                  motion-sum                   motion-mean
# 6                  motion-sum                    motion-max
# 7                 motion-mean                    motion-max
# 8                    step-sum                      step-max
# 9                   step-mean                      step-max
# 10  Time spent outside (mins)  distance travelled from home
# 11                    l2_mean                        l2_sum
# 12                    l2_mean                     l2_energy
# 13                    l2_mean                   l2_skewness
# 14                    l2_mean                        l2_rms
# 15                    l2_mean               l2_n_above_mean
# 16                    l2_mean               l2_n_below_mean
# 17                    l2_mean                    l2_entropy
# 18                    l2_mean               l2_perm_entropy
# 19                     l2_std                        l2_iqr
# 20                     l2_max                        l2_ptp
# 21                     l2_sum                     l2_energy
# 22                     l2_sum                   l2_skewness
# 23                     l2_sum                        l2_rms
# 24                     l2_sum               l2_n_above_mean
# 25                     l2_sum               l2_n_below_mean
# 26                     l2_sum                    l2_entropy
# 27                     l2_sum               l2_perm_entropy
# 28                  l2_energy                   l2_skewness
# 29                  l2_energy                        l2_rms
# 30                  l2_energy               l2_n_above_mean
# 31                  l2_energy               l2_n_below_mean
# 32                  l2_energy                    l2_entropy
# 33                  l2_energy               l2_perm_entropy
# 34                l2_skewness                        l2_rms
# 35                l2_skewness               l2_n_above_mean
# 36                l2_skewness               l2_n_below_mean
# 37                l2_skewness                    l2_entropy
# 38                l2_skewness               l2_perm_entropy
# 39                   l2_peaks               l2_lineintegral
# 40                     l2_rms               l2_n_above_mean
# 41                     l2_rms               l2_n_below_mean
# 42                     l2_rms                    l2_entropy
# 43                     l2_rms               l2_perm_entropy
# 44            l2_n_above_mean               l2_n_below_mean
# 45            l2_n_above_mean                    l2_entropy
# 46            l2_n_above_mean               l2_perm_entropy
# 47            l2_n_below_mean                    l2_entropy
# 48            l2_n_below_mean               l2_perm_entropy
# 49                l2_iqr_5_95                     l2_pct_95
# 50                 l2_entropy               l2_perm_entropy

# %%
columns_to_drop = redundant_pairs_df['Column 2'].explode().unique()

# %%
columns_to_drop
# Out:
# array(['position-duration', 'Time spent outside (mins)',
#        'distance travelled from home', 'motion-mean', 'motion-max',
#        'step-max', 'l2_sum', 'l2_energy', 'l2_skewness', 'l2_rms',
#        'l2_n_above_mean', 'l2_n_below_mean', 'l2_entropy',
#        'l2_perm_entropy', 'l2_iqr', 'l2_ptp', 'l2_lineintegral',
#        'l2_pct_95'], dtype=object)

# %%
correlation_matrix_df = correlation_matrix_df.drop(columns=columns_to_drop, index=columns_to_drop)
correlation_matrix_df.to_excel('CorrMatrix-Daily-AllFractures-wrtOHS&OKS-thres-0.9.xlsx')

# %%
correlation_matrix_df
# Out:
#                            position-count  position-maximum-distance  \
# position-count                   1.000000                   0.807925
# position-maximum-distance        0.807925                   1.000000
# motion-sum                       0.140849                   0.210993
# motion-ratio                     0.000000                   0.000000
# motion-max-timestamp             0.000000                   0.000000
# ...                                   ...                        ...
# oks-12                           0.000000                   0.000000
# oks                              0.000000                   0.000000
# tug                              0.000000                   0.000000
# chairstand                       0.000000                   0.000000
# sex                              0.000000                  -0.143429
#
#                            motion-sum  motion-ratio  motion-max-timestamp  \
# position-count               0.140849      0.000000              0.000000
# position-maximum-distance    0.210993      0.000000              0.000000
# motion-sum                   1.000000      0.339678              0.436195
# motion-ratio                 0.339678      1.000000              0.000000
# motion-max-timestamp         0.436195      0.000000              1.000000
# ...                               ...           ...                   ...
# oks-12                       0.352965     -0.278429              0.270039
# oks                          0.280779     -0.442033              0.341299
# tug                          0.402421      0.162845              0.222999
# chairstand                  -0.226646     -0.351745              0.000000
# sex                          0.000000     -0.206125              0.264915
#
#                            heartrate-min  heartrate-max  heartrate-mean  \
# position-count                  0.000000       0.000000        0.000000
# position-maximum-distance       0.000000       0.000000        0.133428
# motion-sum                      0.000000       0.122864        0.000000
# motion-ratio                   -0.267630      -0.145652       -0.274434
# motion-max-timestamp            0.000000       0.000000        0.000000
# ...                                  ...            ...             ...
# oks-12                          0.387567       0.370899        0.442963
# oks                             0.319038       0.239699        0.329499
# tug                             0.000000       0.000000        0.000000
# chairstand                      0.169451       0.000000        0.187696
# sex                             0.126309       0.151419        0.125606
#
#                            heartrate-std  totalsleepduration  ...    oks-07  \
# position-count                  0.000000            0.000000  ...  0.000000
# position-maximum-distance       0.000000            0.000000  ... -0.174589
# motion-sum                      0.000000           -0.232538  ... -0.295007
# motion-ratio                    0.000000            0.000000  ... -0.489956
# motion-max-timestamp            0.000000           -0.223082  ...  0.000000
# ...                                  ...                 ...  ...       ...
# oks-12                          0.000000           -0.153119  ...  0.424400
# oks                             0.000000            0.000000  ...  0.380855
# tug                             0.121149           -0.593562  ... -0.132440
# chairstand                      0.000000            0.307176  ...  0.383099
# sex                             0.000000            0.215705  ...  0.172514
#
#                              oks-08    oks-09    oks-10    oks-11    oks-12  \
# position-count             0.218864  0.148139  0.214737  0.000000  0.000000
# position-maximum-distance  0.204322  0.000000  0.243063  0.000000  0.000000
# motion-sum                 0.402982  0.299288  0.631509  0.210568  0.352965
# motion-ratio               0.000000 -0.376669  0.171569 -0.502535 -0.278429
# motion-max-timestamp       0.229028  0.253952  0.179267  0.266482  0.270039
# ...                             ...       ...       ...       ...       ...
# oks-12                     0.319516  0.547086  0.395057  0.652800  1.000000
# oks                        0.541133  0.821926  0.254830  0.885465  0.704893
# tug                       -0.206147 -0.189662  0.000000  0.000000 -0.126480
# chairstand                 0.000000  0.274197  0.000000  0.278183  0.239828
# sex                        0.297441  0.363935  0.222964  0.323602  0.422252
#
#                                 oks       tug  chairstand       sex
# position-count             0.000000  0.000000    0.000000  0.000000
# position-maximum-distance  0.000000  0.000000    0.000000 -0.143429
# motion-sum                 0.280779  0.402421   -0.226646  0.000000
# motion-ratio              -0.442033  0.162845   -0.351745 -0.206125
# motion-max-timestamp       0.341299  0.222999    0.000000  0.264915
# ...                             ...       ...         ...       ...
# oks-12                     0.704893 -0.126480    0.239828  0.422252
# oks                        1.000000  0.000000    0.216994  0.421711
# tug                        0.000000  1.000000   -0.532319 -0.596897
# chairstand                 0.216994 -0.532319    1.000000  0.389841
# sex                        0.421711 -0.596897    0.389841  1.000000
#
# [72 rows x 72 columns]

# %%
# Save the correlation matrix to an Excel file with heatmap
excel_filename = 'CorrMatrix-Daily-AllFractures-wrtOHS&OKS-thres-0.9-heatmap.xlsx'
correlation_matrix_df.to_excel(excel_filename, sheet_name='Correlation Matrix')

# Open the Excel workbook and select the active sheet
wb = Workbook()
ws = wb.active

# Create a color map for seaborn heatmap
cmap = sns.color_palette("coolwarm", as_cmap=True)

# Apply color formatting to the Excel cells based on the seaborn heatmap
for row_idx, row in enumerate(correlation_matrix_df.index, start=2):
    for col_idx, col in enumerate(correlation_matrix_df.columns, start=2):
        cell = ws.cell(row=row_idx, column=col_idx)
        value = correlation_matrix_df.at[row, col]
        # Normalize the correlation value to the range [0, 1]
        normalized_value = (value + 1) / 2
        # Map the normalized value to RGB color using the seaborn colormap
        rgb_color = cmap(normalized_value)[:3]
        # Convert RGB to aRGB by adding an alpha channel (255)
        argb_color = (255,) + tuple(int(255 * x) for x in rgb_color)
        # Convert aRGB to HEX
        hex_color = '%02x%02x%02x%02x' % argb_color
        # Apply fill color to the cell
        cell.fill = PatternFill(start_color=hex_color, end_color=hex_color, fill_type="solid")

# Save the modified Excel file
wb.save(excel_filename)

wb.close()
