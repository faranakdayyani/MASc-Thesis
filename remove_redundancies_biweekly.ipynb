# %%
import numpy as np
import pandas as pd

import seaborn as sns

from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.styles import PatternFill
from openpyxl.drawing.image import Image

# %%
def find_redundant_pairs(correlation_matrix, threshold):
    redundant_pairs = []
    # Iterate through the upper triangle of the correlation matrix
    for i in range(len(correlation_matrix.columns)):
        for j in range(i+1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) >= threshold:
                redundant_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j]))
    return redundant_pairs

# %%
# Read correlation matrix from CSV file
correlation_matrix_df = pd.read_excel('filt_CorrMatrix-Biweekly-AllFractures-wrt30sec_heatmap.xlsx', index_col=0)
correlation_matrix_df.head()
# Out:
#                            Type of fracture  position-count  \
# Type of fracture                        1.0        0.000000
# position-count                          0.0        1.000000
# position-duration                       0.0        0.953821
# position-maximum-distance               0.0        0.000000
# Time spent outside (mins)               0.0        0.948281
#
#                            position-duration  position-maximum-distance  \
# Type of fracture                    0.000000                        0.0
# position-count                      0.953821                        0.0
# position-duration                   1.000000                        0.0
# position-maximum-distance           0.000000                        1.0
# Time spent outside (mins)           0.971872                        0.0
#
#                            Time spent outside (mins)  \
# Type of fracture                            0.000000
# position-count                              0.948281
# position-duration                           0.971872
# position-maximum-distance                   0.000000
# Time spent outside (mins)                   1.000000
#
#                            distance travelled from home  motion-sum  \
# Type of fracture                              -0.473861    0.000000
# position-count                                 0.000000    0.000000
# position-duration                              0.000000    0.000000
# position-maximum-distance                      0.564417    0.504375
# Time spent outside (mins)                      0.000000    0.000000
#
#                            motion-ratio  motion-mean  motion-max  ...  oks-07  \
# Type of fracture                    0.0          0.0         0.0  ...     0.0
# position-count                      0.0          0.0         0.0  ...     0.0
# position-duration                   0.0          0.0         0.0  ...     0.0
# position-maximum-distance           0.0          0.0         0.0  ...     0.0
# Time spent outside (mins)           0.0          0.0         0.0  ...     0.0
#
#                            oks-08  oks-09    oks-10  oks-11  oks-12  oks  \
# Type of fracture              0.0     0.0  0.000000     0.0     0.0  0.0
# position-count                0.0     0.0  0.000000     0.0     0.0  0.0
# position-duration             0.0     0.0  0.000000     0.0     0.0  0.0
# position-maximum-distance     0.0     0.0  0.630652     0.0     0.0  0.0
# Time spent outside (mins)     0.0     0.0  0.000000     0.0     0.0  0.0
#
#                                 tug  chairstand       sex
# Type of fracture           0.778652         0.0 -0.492086
# position-count             0.000000         0.0  0.000000
# position-duration          0.000000         0.0  0.000000
# position-maximum-distance  0.000000         0.0  0.000000
# Time spent outside (mins)  0.000000         0.0  0.000000
#
# [5 rows x 91 columns]

# %%
# Find redundant pairs
redundant_pairs = find_redundant_pairs(correlation_matrix_df, threshold=0.9)

# %%
redundant_pairs_df = pd.DataFrame(redundant_pairs, columns=['Column 1', 'Column 2'])
redundant_pairs_df
# Out:
#              Column 1                   Column 2
# 0      position-count          position-duration
# 1      position-count  Time spent outside (mins)
# 2   position-duration  Time spent outside (mins)
# 3          motion-sum                motion-mean
# 4             l2_mean                     l2_sum
# 5             l2_mean                  l2_energy
# 6             l2_mean                l2_skewness
# 7             l2_mean                     l2_rms
# 8             l2_mean            l2_n_above_mean
# 9             l2_mean            l2_n_below_mean
# 10            l2_mean                 l2_entropy
# 11             l2_std                l2_kurtosis
# 12             l2_max                     l2_ptp
# 13             l2_sum                  l2_energy
# 14             l2_sum                l2_skewness
# 15             l2_sum                     l2_rms
# 16             l2_sum            l2_n_above_mean
# 17             l2_sum            l2_n_below_mean
# 18             l2_sum                 l2_entropy
# 19          l2_energy                l2_skewness
# 20          l2_energy                     l2_rms
# 21          l2_energy            l2_n_above_mean
# 22          l2_energy            l2_n_below_mean
# 23        l2_skewness                     l2_rms
# 24        l2_skewness            l2_n_above_mean
# 25        l2_skewness            l2_n_below_mean
# 26        l2_skewness                 l2_entropy
# 27           l2_peaks            l2_lineintegral
# 28             l2_rms            l2_n_above_mean
# 29             l2_rms            l2_n_below_mean
# 30             l2_rms                 l2_entropy
# 31             l2_rms            l2_perm_entropy
# 32    l2_n_above_mean            l2_n_below_mean
# 33    l2_n_above_mean                 l2_entropy
# 34    l2_n_above_mean            l2_perm_entropy
# 35    l2_n_below_mean                 l2_entropy
# 36    l2_n_below_mean            l2_perm_entropy
# 37         l2_entropy            l2_perm_entropy

# %%
columns_to_drop = redundant_pairs_df['Column 2'].explode().unique()

# %%
columns_to_drop
# Out:
# array(['position-duration', 'Time spent outside (mins)', 'motion-mean',
#        'l2_sum', 'l2_energy', 'l2_skewness', 'l2_rms', 'l2_n_above_mean',
#        'l2_n_below_mean', 'l2_entropy', 'l2_kurtosis', 'l2_ptp',
#        'l2_lineintegral', 'l2_perm_entropy'], dtype=object)

# %%
correlation_matrix_df = correlation_matrix_df.drop(columns=columns_to_drop, index=columns_to_drop)
correlation_matrix_df.to_excel('CorrMatrix-Biweekly-AllFractures-wrt30sec-thres-0.9.xlsx')

# %%
correlation_matrix_df
# Out:
#                               Type of fracture  position-count  \
# Type of fracture                      1.000000             0.0
# position-count                        0.000000             1.0
# position-maximum-distance             0.000000             0.0
# distance travelled from home         -0.473861             0.0
# motion-sum                            0.000000             0.0
# ...                                        ...             ...
# oks-12                                0.000000             0.0
# oks                                   0.000000             0.0
# tug                                   0.778652             0.0
# chairstand                            0.000000             0.0
# sex                                  -0.492086             0.0
#
#                               position-maximum-distance  \
# Type of fracture                               0.000000
# position-count                                 0.000000
# position-maximum-distance                      1.000000
# distance travelled from home                   0.564417
# motion-sum                                     0.504375
# ...                                                 ...
# oks-12                                         0.000000
# oks                                            0.000000
# tug                                            0.000000
# chairstand                                     0.000000
# sex                                            0.000000
#
#                               distance travelled from home  motion-sum  \
# Type of fracture                                 -0.473861    0.000000
# position-count                                    0.000000    0.000000
# position-maximum-distance                         0.564417    0.504375
# distance travelled from home                      1.000000    0.000000
# motion-sum                                        0.000000    1.000000
# ...                                                    ...         ...
# oks-12                                            0.526492    0.000000
# oks                                               0.455753    0.000000
# tug                                              -0.461513    0.000000
# chairstand                                        0.000000    0.000000
# sex                                               0.000000    0.000000
#
#                               motion-ratio  motion-max  motion-max-timestamp  \
# Type of fracture                  0.000000    0.000000              0.000000
# position-count                    0.000000    0.000000              0.000000
# position-maximum-distance         0.000000    0.000000              0.000000
# distance travelled from home      0.000000    0.000000              0.000000
# motion-sum                        0.000000    0.806597              0.536856
# ...                                    ...         ...                   ...
# oks-12                            0.000000    0.524933              0.000000
# oks                               0.000000    0.574827              0.000000
# tug                               0.000000    0.000000              0.000000
# chairstand                       -0.520324    0.000000              0.000000
# sex                               0.000000    0.000000              0.505792
#
#                               step-sum  step-ratio  ...  oks-07    oks-08  \
# Type of fracture              0.000000    0.000000  ...     0.0  0.000000
# position-count                0.000000    0.000000  ...     0.0  0.000000
# position-maximum-distance     0.000000    0.000000  ...     0.0  0.000000
# distance travelled from home  0.000000    0.850522  ...     0.0  0.000000
# motion-sum                    0.000000    0.000000  ...     0.0  0.000000
# ...                                ...         ...  ...     ...       ...
# oks-12                        0.646769    0.000000  ...     0.0  0.000000
# oks                           0.563858    0.000000  ...     0.0  0.556703
# tug                          -0.503741   -0.506976  ...     0.0  0.000000
# chairstand                    0.000000    0.000000  ...     0.0  0.000000
# sex                           0.000000    0.000000  ...     0.0  0.000000
#
#                                 oks-09    oks-10    oks-11    oks-12  \
# Type of fracture              0.000000  0.000000  0.000000  0.000000
# position-count                0.000000  0.000000  0.000000  0.000000
# position-maximum-distance     0.000000  0.630652  0.000000  0.000000
# distance travelled from home  0.000000  0.662698  0.000000  0.526492
# motion-sum                    0.000000  0.639676  0.000000  0.000000
# ...                                ...       ...       ...       ...
# oks-12                        0.576292  0.452222  0.663477  1.000000
# oks                           0.834979  0.000000  0.880634  0.703311
# tug                           0.000000  0.000000  0.000000  0.000000
# chairstand                    0.000000  0.000000  0.000000  0.000000
# sex                           0.000000  0.000000  0.000000  0.000000
#
#                                    oks       tug  chairstand       sex
# Type of fracture              0.000000  0.778652         0.0 -0.492086
# position-count                0.000000  0.000000         0.0  0.000000
# position-maximum-distance     0.000000  0.000000         0.0  0.000000
# distance travelled from home  0.455753 -0.461513         0.0  0.000000
# motion-sum                    0.000000  0.000000         0.0  0.000000
# ...                                ...       ...         ...       ...
# oks-12                        0.703311  0.000000         0.0  0.000000
# oks                           1.000000  0.000000         0.0  0.000000
# tug                           0.000000  1.000000         0.0 -0.550116
# chairstand                    0.000000  0.000000         1.0  0.000000
# sex                           0.000000 -0.550116         0.0  1.000000
#
# [77 rows x 77 columns]

# %%
# Save the correlation matrix to an Excel file with heatmap
excel_filename = 'CorrMatrix-Biweekly-AllFractures-wrt30sec-thres-0.9-heatmap.xlsx'
correlation_matrix_df.to_excel(excel_filename, sheet_name='Correlation Matrix')

# Open the Excel workbook and select the active sheet
wb = Workbook()
ws = wb.active

# Create a color map for seaborn heatmap
cmap = sns.color_palette("coolwarm", as_cmap=True)

# Apply color formatting to the Excel cells based on the seaborn heatmap
for row_idx, row in enumerate(correlation_matrix_df.index, start=2):
    for col_idx, col in enumerate(correlation_matrix_df.columns, start=2):
        cell = ws.cell(row=row_idx, column=col_idx)
        value = correlation_matrix_df.at[row, col]
        # Normalize the correlation value to the range [0, 1]
        normalized_value = (value + 1) / 2
        # Map the normalized value to RGB color using the seaborn colormap
        rgb_color = cmap(normalized_value)[:3]
        # Convert RGB to aRGB by adding an alpha channel (255)
        argb_color = (255,) + tuple(int(255 * x) for x in rgb_color)
        # Convert aRGB to HEX
        hex_color = '%02x%02x%02x%02x' % argb_color
        # Apply fill color to the cell
        cell.fill = PatternFill(start_color=hex_color, end_color=hex_color, fill_type="solid")

# Save the modified Excel file
wb.save(excel_filename)

wb.close()
